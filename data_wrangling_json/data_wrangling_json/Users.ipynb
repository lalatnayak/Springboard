# %%
# %matplotlib inline
import pandas as pd
import json
from pandas.io.json import json_normalize
from IPython.core.display import HTML

# %%
f = open('data/users1.json', 'r', encoding='utf-8')
data = f.read()
jsonData = json.loads(data)
df = json_normalize(jsonData, 'records')
f.close()
df
# Out:
#     base64RowVersion     id isLocked jobs               lastLoginDate  \
# 0       AAAAAAfYKfQ=  59224    False   []  2016-12-01T06:58:17.167543
# 1       AAAAAAfYKAM=  59223    False   []  2016-12-01T15:58:10.215307
# 2       AAAAAAfYHbg=  59222    False   []  2016-12-01T16:55:03.193864
# 3       AAAAAAfYFdc=  59221    False   []  2016-11-29T15:05:11.920038
# 4       AAAAAAfYFR8=  59220    False   []  2016-12-01T16:54:21.508712
# 5       AAAAAAfX9Ec=  59219    False   []  2016-12-02T04:14:37.273194
# 6       AAAAAAfX4lI=  59218    False   []  2016-12-02T04:16:44.663459
# 7       AAAAAAfX4kA=  59217    False   []  2016-12-01T14:23:13.812467
# 8       AAAAAAfX4Zk=  59216    False   []  2016-12-01T15:47:38.902538
# 9       AAAAAAfX378=  59215    False   []  2016-12-01T15:38:25.786115
# 10      AAAAAAfX0Bk=  59214    False   []   2016-12-02T07:43:34.68256
# 11      AAAAAAfXvbg=  59213    False   []  2016-12-01T15:38:28.226983
# ...
