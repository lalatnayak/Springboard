# %%
# %matplotlib inline

# %%
from pylab import *

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
from pylab import *

# %%
x = np.linspace(0, 5, 10)
y = x ** 2

# %%
figure()
plot(x, y, 'r')
xlabel('x')
ylabel('y')
title('title')
show()

# %%
fig = plt.figure()

axes = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # left, bottom, width, height (range 0 to 1)

axes.plot(x, y, 'r')

axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('title');

# %%
fig = plt.figure()

axes = fig.add_axes([0.5, 0.5, 0.8, 0.8]) # left, bottom, width, height (range 0 to 1)

axes.plot(x, y, 'r')

axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('title');

# %%
fig = plt.figure()

axes = fig.add_axes([1, 1, 1, 1]) # left, bottom, width, height (range 0 to 1)

axes.plot(x, y, 'r')

axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('title');

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # main axes
axes2 = fig.add_axes([0.2, 0.5, 0.4, 0.3]) # inset axes

# main figure
axes1.plot(x, y, 'r')
axes1.set_xlabel('x')
axes1.set_ylabel('y')
axes1.set_title('title')

# insert
axes2.plot(y, x, 'g')
axes2.set_xlabel('y')
axes2.set_ylabel('x')
axes2.set_title('insert title');

# %%
ax.plot(x, x**2, label="curve1")
ax.plot(x, x**3, label="curve2")
ax.legend();
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-12b1eb84f0d2> in <module>()
# ----> 1 ax.plot(x, x**2, label="curve1")
#       2 ax.plot(x, x**3, label="curve2")
#       3 ax.legend();
#
# NameError: name 'ax' is not defined

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)

for ax in axes:
    ax.plot(x, x**2, label=r"$y = \alpha^2$", linewidth=1, marker='o')
    ax.plot(x, np.exp(x), label=r"$y = 10^\alpha$", linewidth=1, marker='o')
    ax.set_xlabel(r'$\alpha$', fontsize=18)
    ax.set_ylabel(r'$y$', fontsize=18)
    ax.set_yscale("log")
    ax.legend(loc=2);
fig.tight_layout()

# %%
fig, axes = plt.subplots(1, 2)

for ax in axes:
    ax.plot(x, x**2, label=r"$y = \alpha^2$", linewidth=1, marker='o')
    ax.plot(x, np.exp(x), label=r"$y = 10^\alpha$", linewidth=1, marker='o')
    ax.set_xlabel(r'$\alpha$', fontsize=18)
    ax.set_ylabel(r'$y$', fontsize=18)
    ax.set_yscale("log")
    ax.legend(loc=2);
fig.tight_layout()

# %%
fig, axes = plt.subplots(1, 2, figsize=(8,8))

for ax in axes:
    ax.plot(x, x**2, label=r"$y = \alpha^2$", linewidth=1, marker='o')
    ax.plot(x, np.exp(x), label=r"$y = 10^\alpha$", linewidth=1, marker='o')
    ax.set_xlabel(r'$\alpha$', fontsize=18)
    ax.set_ylabel(r'$y$', fontsize=18)
    ax.set_yscale("log")
    ax.legend(loc=2);
fig.tight_layout()

# %%
fig, axes = plt.subplots(1, 2, figsize=(8,4))

for ax in axes:
    ax.plot(x, x**2, label=r"$y = \alpha^2$", linewidth=1, marker='o')
    ax.plot(x, np.exp(x), label=r"$y = 10^\alpha$", linewidth=1, marker='o')
    ax.set_xlabel(r'$\alpha$', fontsize=18)
    ax.set_ylabel(r'$y$', fontsize=18)
    ax.set_yscale("log")
    ax.legend(loc=2);
fig.tight_layout()

# %%
fig, axes = plt.subplots(2, 2, figsize=(8,4))

for ax in axes:
    ax.plot(x, x**2, label=r"$y = \alpha^2$", linewidth=1, marker='o')
    ax.plot(x, np.exp(x), label=r"$y = 10^\alpha$", linewidth=1, marker='o')
    ax.set_xlabel(r'$\alpha$', fontsize=18)
    ax.set_ylabel(r'$y$', fontsize=18)
    ax.set_yscale("log")
    ax.legend(loc=2);
fig.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-3d5fa5c83ab6> in <module>()
#       2
#       3 for ax in axes:
# ----> 4     ax.plot(x, x**2, label=r"$y = \alpha^2$", linewidth=1, marker='o')
#       5     ax.plot(x, np.exp(x), label=r"$y = 10^\alpha$", linewidth=1, marker='o')
#       6     ax.set_xlabel(r'$\alpha$', fontsize=18)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'plot'

# %%
fig, axes = plt.subplots(2, 2, figsize=(8,4))

# %%
axes
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000008FA84A8>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000E5B01D0>]], dtype=object)

# %%
axes[0][0]

# %%
axes[0][1]

# %%
axes[2]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-34-bd8cb6abe611> in <module>()
# ----> 1 axes[2]
#
# IndexError: index 2 is out of bounds for axis 0 with size 2

# %%
fig, axes = plt.subplots(2, 2, figsize=(8,4))

for i in range(0,2):
    for j in range(0,2):
        axes[i][j].plot(x, x**2, label=r"$y = \alpha^2$", linewidth=1, marker='o')
        axes[i][j].plot(x, np.exp(x), label=r"$y = 10^\alpha$", linewidth=1, marker='o')
        axes[i][j].set_xlabel(r'$\alpha$', fontsize=18)
        axes[i][j].set_ylabel(r'$y$', fontsize=18)
        axes[i][j].set_yscale("log")
        axes[i][j].legend(loc=2);
fig.tight_layout()

# %%
fig, ax = plt.subplots()

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0)) # set position of x spine to x=0

ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))   # set position of y spine to y=0
xx = np.linspace(-0.75, 1, 100)
ax.plot(xx, xx**3);

# %%
n = np.array([0,1,2,3,4,5])
fig, axes = plt.subplots(1, 4, figsize=(12,3))

axes[0].scatter(xx, xx + 0.25*np.random.randn(len(xx)))
axes[0].set_title("scatter")

axes[1].step(n, n**2, lw=2)
axes[1].set_title("step")

axes[2].bar(n, n**2, align="center", width=0.5, alpha=0.5)
axes[2].set_title("bar")

axes[3].fill_between(x, x**2, x**3, color="green", alpha=0.5);
axes[3].set_title("fill_between");

# %%
# polar plot using add_axes and polar projection
fig = plt.figure()
ax = fig.add_axes([0.0, 0.0, .6, .6], polar=True)
t = np.linspace(0, 2 * np.pi, 100)
ax.plot(t, t, color='blue', lw=2);

# %%
# A histogram
n = np.random.randn(100000)
fig, axes = plt.subplots(1, 2, figsize=(12,4))

axes[0].hist(n)
axes[0].set_title("Default histogram")
axes[0].set_xlim((min(n), max(n)))

axes[1].hist(n, cumulative=True, bins=50)
axes[1].set_title("Cumulative detailed histogram")
axes[1].set_xlim((min(n), max(n)));

# %%
fig, ax = plt.subplots()

ax.plot(xx, xx**2, xx, xx**3)

ax.text(0.15, 0.2, r"$y=x^2$", fontsize=20, color="blue")
ax.text(0.65, 0.1, r"$y=x^3$", fontsize=20, color="green");

# %%
fig, ax = plt.subplots()

ax.plot(xx, xx**2, xx, xx**3)
fig.tight_layout()

# inset
inset_ax = fig.add_axes([0.2, 0.55, 0.35, 0.35]) # X, Y, width, height

inset_ax.plot(xx, xx**2, xx, xx**3)
inset_ax.set_title('zoom near origin')

# set axis range
inset_ax.set_xlim(-.2, .2)
inset_ax.set_ylim(-.005, .01)

# set axis tick locations
inset_ax.set_yticks([0, 0.005, 0.01])
inset_ax.set_xticks([-0.1,0,.1]);

# %%
from mpl_toolkits.mplot3d.axes3d import Axes3D

# %%
alpha = 0.7
phi_ext = 2 * np.pi * 0.5

def flux_qubit_potential(phi_m, phi_p):
    return 2 + alpha - 2 * np.cos(phi_p) * np.cos(phi_m) - alpha * np.cos(phi_ext - 2*phi_p)

# %%
phi_m = np.linspace(0, 2*np.pi, 100)
phi_p = np.linspace(0, 2*np.pi, 100)
X,Y = np.meshgrid(phi_p, phi_m)
Z = flux_qubit_potential(X, Y).T

# %%
fig, ax = plt.subplots()

p = ax.pcolor(X/(2*np.pi), Y/(2*np.pi), Z, cmap=matplotlib.cm.RdBu, vmin=abs(Z).min(), vmax=abs(Z).max())
cb = fig.colorbar(p, ax=ax)

# %%
phi_p
# Out:
# array([ 0.        ,  0.06346652,  0.12693304,  0.19039955,  0.25386607,
#         0.31733259,  0.38079911,  0.44426563,  0.50773215,  0.57119866,
#         0.63466518,  0.6981317 ,  0.76159822,  0.82506474,  0.88853126,
#         0.95199777,  1.01546429,  1.07893081,  1.14239733,  1.20586385,
#         1.26933037,  1.33279688,  1.3962634 ,  1.45972992,  1.52319644,
#         1.58666296,  1.65012947,  1.71359599,  1.77706251,  1.84052903,
#         1.90399555,  1.96746207,  2.03092858,  2.0943951 ,  2.15786162,
#         2.22132814,  2.28479466,  2.34826118,  2.41172769,  2.47519421,
#         2.53866073,  2.60212725,  2.66559377,  2.72906028,  2.7925268 ,
#         2.85599332,  2.91945984,  2.98292636,  3.04639288,  3.10985939,
#         3.17332591,  3.23679243,  3.30025895,  3.36372547,  3.42719199,
#         3.4906585 ,  3.55412502,  3.61759154,  3.68105806,  3.74452458,
#         3.8079911 ,  3.87145761,  3.93492413,  3.99839065,  4.06185717,
# ...

# %%
X[0][0]
# Out:
# 0.0

# %%
X[0][1]
# Out:
# 0.063466518254339258

# %%
X[0][99]
# Out:
# 6.2831853071795862

# %%
X[1][0]
# Out:
# 0.0

# %%
X[1][1]
# Out:
# 0.063466518254339258

# %%
X[1][99]
# Out:
# 6.2831853071795862

# %%
X[99][99]
# Out:
# 6.2831853071795862

# %%
X
# Out:
# array([[ 0.        ,  0.06346652,  0.12693304, ...,  6.15625227,
#          6.21971879,  6.28318531],
#        [ 0.        ,  0.06346652,  0.12693304, ...,  6.15625227,
#          6.21971879,  6.28318531],
#        [ 0.        ,  0.06346652,  0.12693304, ...,  6.15625227,
#          6.21971879,  6.28318531],
#        ...,
#        [ 0.        ,  0.06346652,  0.12693304, ...,  6.15625227,
#          6.21971879,  6.28318531],
#        [ 0.        ,  0.06346652,  0.12693304, ...,  6.15625227,
#          6.21971879,  6.28318531],
#        [ 0.        ,  0.06346652,  0.12693304, ...,  6.15625227,
#          6.21971879,  6.28318531]])

# %%
Y
# Out:
# array([[ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.06346652,  0.06346652,  0.06346652, ...,  0.06346652,
#          0.06346652,  0.06346652],
#        [ 0.12693304,  0.12693304,  0.12693304, ...,  0.12693304,
#          0.12693304,  0.12693304],
#        ...,
#        [ 6.15625227,  6.15625227,  6.15625227, ...,  6.15625227,
#          6.15625227,  6.15625227],
#        [ 6.21971879,  6.21971879,  6.21971879, ...,  6.21971879,
#          6.21971879,  6.21971879],
#        [ 6.28318531,  6.28318531,  6.28318531, ...,  6.28318531,
#          6.28318531,  6.28318531]])
